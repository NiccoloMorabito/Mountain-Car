# %%
# !pip install gym[classic_control]
# !apt-get install x11-utils
# !pip install pyglet
# !apt-get install -y xvfb python-opengl
# !pip install gym pyvirtualdisplay

# %%
import gym
from keras import models
from keras import layers
from keras.optimizers import Adam
from collections import deque
import random
import numpy as np

import tensorflow as tf
tf.keras.utils.disable_interactive_logging()

import keras
config = tf.compat.v1.ConfigProto( device_count = {'GPU': 2 , 'CPU': 1} ) 
sess = tf.compat.v1.Session(config=config) 
keras.backend.set_session(sess)

# %%
'''To render the interaction with the environment in a Jupyter Notebook'''

import imageio
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# To get smooth animations
mpl.rc('animation', html='jshtml')
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

def plot_animation(model, environment, gif_name=None, seed=1):
    environment.seed(seed)
    np.random.seed(seed)
    frames = render_policy_net(model, environment)

    # saving gif
    if not gif_name:
        gif_name = "DQN.gif"
    imageio.mimsave(gif_name, frames, fps=30)
    
    # plotting animation
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')
    anim = animation.FuncAnimation(
        fig, update_scene, fargs=(frames, patch),
        frames=len(frames), repeat=True, interval=40)
    plt.close()

    return anim

def render_policy_net(model, env, n_max_steps=200):
    frames = list()

    obs = env.reset()
    for step in range(n_max_steps):
        frames.append(env.render(mode="rgb_array"))
        action = np.argmax(model.predict(obs[np.newaxis])[0])
        obs, reward, done, info = env.step(action)
        if done:
            break
    return frames

def update_scene(num, frames, patch):
    patch.set_data(frames[num])
    return patch

# %%
NUM_EPISODES = 400
NUM_ITERATIONS = 201 #max is 200

# %%
class MountainCarAgentDQN:
    def __init__(self, env):
        self.state_size = env.observation_space.shape[0]
        self.action_size = env.action_space.n

        self.gamma = 0.99
        self.learning_rate = 0.001

        self.epsilon = 1
        self.epsilon_decay = 0.05
        self.epsilon_min=0.01

        self.replay_buffer = deque(maxlen=20000)

        self.batch_size = 32

        # networks
        self.train_network = self.create_model()
        self.target_network = self.create_model()
        self.sync_networks()

    def create_model(self):
        model = models.Sequential()
        model.add(layers.Dense(24, activation='relu', input_shape=[self.state_size]))
        model.add(layers.Dense(48, activation='relu'))
        model.add(layers.Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model
    
    def sync_networks(self):
        self.target_network.set_weights(self.train_network.get_weights())

    def get_next_action(self, state):
        self.epsilon = max(self.epsilon_min, self.epsilon)

        if np.random.rand() < self.epsilon:
            action = np.random.randint(self.action_size)
        else:
            action = np.argmax(self.train_network.predict(state[np.newaxis])[0])

        return action
    
    def store_in_replay(self, current_state, next_action, reward, new_state, done):
      self.replay_buffer.append([current_state, next_action, reward, new_state, done])

    def train(self):
        # only when the replay memory has enough experience
        if len(self.replay_buffer) < self.batch_size:
            return
        
        states, actions, rewards, next_states, dones = self.sample_experiences()

        # compute the boostrap targets
        new_targets = self.target_network.predict(next_states) # next Q values
        max_next_Q_values = np.max(new_targets, axis=1)

        # compute the targets
        targets = self.train_network.predict(states)
        targets[(np.arange(self.batch_size), actions.reshape(self.batch_size,).astype(int))] =\
          rewards + (1 - dones) * self.gamma * max_next_Q_values

        self.train_network.fit(states, targets, epochs=1, verbose=0)
    
    def sample_experiences(self):
        batch = random.sample(self.replay_buffer, self.batch_size)
        states, actions, rewards, next_states, dones = [
            np.array([experience[field_index] for experience in batch])
            for field_index in range(5)]
        return states, actions, rewards, next_states, dones
    
    def end_episode(self, success):
        if success:
            dqn.train_network.save(f'./dqnInEp{episode}.h5')
        self.epsilon -= self.epsilon_decay
        self.sync_networks()
        

env = gym.make('MountainCar-v0')
dqn = MountainCarAgentDQN(env=env)
for episode in range(NUM_EPISODES):
    #save the animation every 50 eps
    #if episode%50==0:
    #    plot_animation(dqn.train_network, env, gif_name=f"DQN_ep{episode}.gif")
    
    current_state = env.reset()

    tot_reward = 0
    max_position=-99

    for iteration in range(NUM_ITERATIONS):
        next_action = dqn.get_next_action(current_state)
        new_state, reward, done, _ = env.step(next_action)

        # # Keep track of max position
        if new_state[0] > max_position:
            max_position = new_state[0]
        # # Adjust reward for task completion
        if new_state[0] >= 0.5:
            reward += 10

        dqn.store_in_replay(current_state, next_action, reward, new_state, done)
        dqn.train()

        tot_reward += reward
        current_state = new_state

        if done:
            break

    if iteration >= 199:
        print(f"Failed to finish task in episode {episode}")
    else:
        print(f"Success in episode {episode}, used {iteration} iterations!")
    print(f"the reward is {tot_reward} maxPosition is {max_position}")

    dqn.end_episode(iteration < 199)

plot_animation(dqn.train_network, env, gif_name=f"DQN_final.gif")

env.close()
# Out:
# /Users/niccolomorabito/Library/Python/3.9/lib/python/site-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 2023-01-08 14:41:04.880201: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Failed to finish task in episode 0
# the reward is -200.0 maxPosition is -0.46404293179512024
# Failed to finish task in episode 1
# the reward is -200.0 maxPosition is -0.4220111668109894
# Failed to finish task in episode 2
# the reward is -200.0 maxPosition is -0.3520282506942749
# Failed to finish task in episode 3
# the reward is -200.0 maxPosition is -0.31948697566986084
# Failed to finish task in episode 4
# the reward is -200.0 maxPosition is -0.1712750494480133
# Failed to finish task in episode 5
# the reward is -200.0 maxPosition is -0.3761269152164459
# Failed to finish task in episode 6
# the reward is -200.0 maxPosition is -0.4116733968257904
# Failed to finish task in episode 7
# the reward is -200.0 maxPosition is -0.27033567428588867
# Failed to finish task in episode 8
# the reward is -200.0 maxPosition is -0.297061562538147
# Failed to finish task in episode 9
# the reward is -200.0 maxPosition is -0.26634955406188965
# Failed to finish task in episode 10
# the reward is -200.0 maxPosition is -0.4082501232624054
# Failed to finish task in episode 11
# the reward is -200.0 maxPosition is -0.28679007291793823
# Failed to finish task in episode 12
# the reward is -200.0 maxPosition is -0.22112369537353516
# Failed to finish task in episode 13
# the reward is -200.0 maxPosition is -0.2562130391597748
# Failed to finish task in episode 14
# the reward is -200.0 maxPosition is -0.0913170725107193
# Failed to finish task in episode 15
# the reward is -200.0 maxPosition is -0.3358500897884369
# Failed to finish task in episode 16
# the reward is -200.0 maxPosition is -0.1274462193250656
# Failed to finish task in episode 17
# the reward is -200.0 maxPosition is 0.0501716211438179
# Failed to finish task in episode 18
# the reward is -200.0 maxPosition is -0.32368165254592896
# Failed to finish task in episode 19
# the reward is -200.0 maxPosition is -0.10708753764629364
# Failed to finish task in episode 20
# the reward is -200.0 maxPosition is 0.23753799498081207
# Failed to finish task in episode 21
# the reward is -200.0 maxPosition is -0.16992942988872528
# Failed to finish task in episode 22
# the reward is -200.0 maxPosition is -0.014463571831583977
# Failed to finish task in episode 23
# the reward is -200.0 maxPosition is 0.052813656628131866
# Failed to finish task in episode 24
# the reward is -200.0 maxPosition is 0.018507445231080055
# Failed to finish task in episode 25
# the reward is -200.0 maxPosition is -0.14945222437381744
# Failed to finish task in episode 26
# the reward is -200.0 maxPosition is -0.17683544754981995
# Failed to finish task in episode 27
# the reward is -200.0 maxPosition is -0.3478185832500458
# Failed to finish task in episode 28
# the reward is -200.0 maxPosition is -0.20367906987667084
# Failed to finish task in episode 29
# the reward is -200.0 maxPosition is -0.2722310721874237
# Failed to finish task in episode 30
# the reward is -200.0 maxPosition is -0.2728259265422821
# Failed to finish task in episode 31
# the reward is -200.0 maxPosition is 0.14242422580718994
# Failed to finish task in episode 32
# the reward is -200.0 maxPosition is -0.24390766024589539
# Failed to finish task in episode 33
# the reward is -200.0 maxPosition is -0.03333749994635582
# Failed to finish task in episode 34
# the reward is -200.0 maxPosition is -0.08946394175291061
# Failed to finish task in episode 35
# the reward is -200.0 maxPosition is -0.2106492668390274
# Failed to finish task in episode 36
# the reward is -200.0 maxPosition is -0.12375392764806747
# Failed to finish task in episode 37
# the reward is -200.0 maxPosition is -0.2817387878894806
# Failed to finish task in episode 38
# the reward is -200.0 maxPosition is -0.14422039687633514
# Failed to finish task in episode 39
# the reward is -200.0 maxPosition is -0.12792369723320007
# Failed to finish task in episode 40
# the reward is -200.0 maxPosition is -0.30731940269470215
# Failed to finish task in episode 41
# the reward is -200.0 maxPosition is 0.019869763404130936
# Failed to finish task in episode 42
# the reward is -200.0 maxPosition is -0.11979571729898453
# Failed to finish task in episode 43
# the reward is -200.0 maxPosition is 0.3855421245098114
# Failed to finish task in episode 44
# the reward is -200.0 maxPosition is -0.3243396580219269
# Failed to finish task in episode 45
# the reward is -200.0 maxPosition is 0.1958107352256775
# Failed to finish task in episode 46
# the reward is -200.0 maxPosition is -0.23262159526348114
# Failed to finish task in episode 47
# the reward is -200.0 maxPosition is -0.12718704342842102
# Failed to finish task in episode 48
# the reward is -200.0 maxPosition is -0.08964754641056061
# Failed to finish task in episode 49
# the reward is -200.0 maxPosition is -0.2941969931125641
# Failed to finish task in episode 50
# the reward is -200.0 maxPosition is -0.23918695747852325
# Failed to finish task in episode 51
# the reward is -200.0 maxPosition is -0.24277514219284058
# Failed to finish task in episode 52
# the reward is -200.0 maxPosition is 0.21476924419403076
# Failed to finish task in episode 53
# the reward is -200.0 maxPosition is -0.16321267187595367
# Failed to finish task in episode 54
# the reward is -200.0 maxPosition is -0.16483430564403534
# Failed to finish task in episode 55
# the reward is -200.0 maxPosition is 0.07217103242874146
# Failed to finish task in episode 56
# the reward is -200.0 maxPosition is -0.3422049880027771
# Failed to finish task in episode 57
# the reward is -200.0 maxPosition is 0.018256057053804398
# Failed to finish task in episode 58
# the reward is -200.0 maxPosition is -0.23003637790679932
# Failed to finish task in episode 59
# the reward is -200.0 maxPosition is -0.31264716386795044
# Failed to finish task in episode 60
# the reward is -200.0 maxPosition is 0.2328011393547058
# Failed to finish task in episode 61
# the reward is -200.0 maxPosition is -0.2279314547777176
# Failed to finish task in episode 62
# the reward is -200.0 maxPosition is -0.012205693870782852
# Failed to finish task in episode 63
# the reward is -200.0 maxPosition is -0.18639534711837769
# Failed to finish task in episode 64
# the reward is -200.0 maxPosition is -0.3077394962310791
# Failed to finish task in episode 65
# the reward is -200.0 maxPosition is -0.32472705841064453
# Success in episode 66, used 194 iterations!
# the reward is -185.0 maxPosition is 0.5017843246459961
# Failed to finish task in episode 67
# the reward is -200.0 maxPosition is 0.006714107468724251
# Failed to finish task in episode 68
# the reward is -200.0 maxPosition is -0.05420628562569618
# Failed to finish task in episode 69
# the reward is -200.0 maxPosition is 0.2050725370645523
# Failed to finish task in episode 70
# the reward is -200.0 maxPosition is 0.05869363993406296
# Failed to finish task in episode 71
# the reward is -200.0 maxPosition is -0.3049239218235016
# Failed to finish task in episode 72
# the reward is -200.0 maxPosition is -0.12400709837675095
# Failed to finish task in episode 73
# the reward is -200.0 maxPosition is 0.17619067430496216
# Failed to finish task in episode 74
# the reward is -200.0 maxPosition is -0.09746623784303665
# Failed to finish task in episode 75
# the reward is -200.0 maxPosition is -0.2709046006202698
# Failed to finish task in episode 76
# the reward is -200.0 maxPosition is -0.2602066099643707
# Failed to finish task in episode 77
# the reward is -200.0 maxPosition is -0.40203773975372314
# Failed to finish task in episode 78
# the reward is -200.0 maxPosition is -0.35191982984542847
# Failed to finish task in episode 79
# the reward is -200.0 maxPosition is -0.06871255487203598
# Failed to finish task in episode 80
# the reward is -200.0 maxPosition is -0.34436336159706116
# Failed to finish task in episode 81
# the reward is -200.0 maxPosition is -0.059304479509592056
# Failed to finish task in episode 82
# the reward is -200.0 maxPosition is -0.20139360427856445
# Failed to finish task in episode 83
# the reward is -200.0 maxPosition is -0.25520965456962585
# Failed to finish task in episode 84
# the reward is -200.0 maxPosition is 0.23052076995372772
# Failed to finish task in episode 85
# the reward is -200.0 maxPosition is 0.01926284283399582
# Failed to finish task in episode 86
# the reward is -200.0 maxPosition is -0.2590913772583008
# Failed to finish task in episode 87
# the reward is -200.0 maxPosition is -0.36263179779052734
# Failed to finish task in episode 88
# the reward is -200.0 maxPosition is 0.14459066092967987
# Failed to finish task in episode 89
# the reward is -200.0 maxPosition is -0.421313613653183
# Failed to finish task in episode 90
# the reward is -200.0 maxPosition is -0.24163006246089935
# Failed to finish task in episode 91
# the reward is -200.0 maxPosition is -0.2358325868844986
# Failed to finish task in episode 92
# the reward is -200.0 maxPosition is -0.08967632055282593
# Failed to finish task in episode 93
# the reward is -200.0 maxPosition is 0.0851500853896141
# Failed to finish task in episode 94
# the reward is -200.0 maxPosition is -0.034680284559726715
# Failed to finish task in episode 95
# the reward is -200.0 maxPosition is 0.09519355744123459
# Failed to finish task in episode 96
# the reward is -200.0 maxPosition is -0.2719862461090088
# Failed to finish task in episode 97
# the reward is -200.0 maxPosition is -0.25329193472862244
# Failed to finish task in episode 98
# the reward is -200.0 maxPosition is -0.09017398953437805
# Failed to finish task in episode 99
# the reward is -200.0 maxPosition is 0.057046473026275635
# Failed to finish task in episode 100
# the reward is -200.0 maxPosition is -0.29583925008773804
# Failed to finish task in episode 101
# the reward is -200.0 maxPosition is -0.12057140469551086
# Failed to finish task in episode 102
# the reward is -200.0 maxPosition is -0.3774094879627228
# Failed to finish task in episode 103
# the reward is -200.0 maxPosition is -0.12412673979997635
# Failed to finish task in episode 104
# the reward is -200.0 maxPosition is -0.05192979797720909
# Failed to finish task in episode 105
# the reward is -200.0 maxPosition is -0.2639419734477997
# Failed to finish task in episode 106
# the reward is -200.0 maxPosition is 0.16312462091445923
# Failed to finish task in episode 107
# the reward is -200.0 maxPosition is -0.1719510853290558
# Failed to finish task in episode 108
# the reward is -200.0 maxPosition is -0.30894434452056885
# Failed to finish task in episode 109
# the reward is -200.0 maxPosition is -0.338323175907135
# Failed to finish task in episode 110
# the reward is -200.0 maxPosition is -0.11169023811817169
# Failed to finish task in episode 111
# the reward is -200.0 maxPosition is -0.13041308522224426
# Failed to finish task in episode 112
# the reward is -200.0 maxPosition is -0.2724297046661377
# Failed to finish task in episode 113
# the reward is -200.0 maxPosition is -0.1341141015291214
# Failed to finish task in episode 114
# the reward is -200.0 maxPosition is -0.25047236680984497
# Failed to finish task in episode 115
# the reward is -200.0 maxPosition is -0.1807284653186798
# Failed to finish task in episode 116
# the reward is -200.0 maxPosition is 0.25902432203292847
# Failed to finish task in episode 117
# the reward is -200.0 maxPosition is 0.012318824417889118
# Failed to finish task in episode 118
# the reward is -200.0 maxPosition is 0.14411048591136932
# Failed to finish task in episode 119
# the reward is -200.0 maxPosition is -0.007092941552400589
# Failed to finish task in episode 120
# the reward is -200.0 maxPosition is -0.32188981771469116
# Failed to finish task in episode 121
# the reward is -200.0 maxPosition is -0.12594296038150787
# Failed to finish task in episode 122
# the reward is -200.0 maxPosition is -0.2878817915916443
# Failed to finish task in episode 123
# the reward is -200.0 maxPosition is 0.3771004378795624
# Failed to finish task in episode 124
# the reward is -200.0 maxPosition is 0.33663272857666016
# Failed to finish task in episode 125
# the reward is -200.0 maxPosition is 0.10323580354452133
# Failed to finish task in episode 126
# the reward is -200.0 maxPosition is -0.28609001636505127
# Failed to finish task in episode 127
# the reward is -200.0 maxPosition is -0.18318119645118713
# Failed to finish task in episode 128
# the reward is -200.0 maxPosition is 0.24223902821540833
# Failed to finish task in episode 129
# the reward is -200.0 maxPosition is -0.209458127617836
# Failed to finish task in episode 130
# the reward is -200.0 maxPosition is -0.09753137081861496
# Success in episode 131, used 148 iterations!
# the reward is -139.0 maxPosition is 0.5042923092842102
# Failed to finish task in episode 132
# the reward is -200.0 maxPosition is 0.15386664867401123
# Failed to finish task in episode 133
# the reward is -200.0 maxPosition is -0.054902367293834686
# Failed to finish task in episode 134
# the reward is -200.0 maxPosition is 0.13013024628162384
# Failed to finish task in episode 135
# the reward is -200.0 maxPosition is -0.2729193866252899
# Failed to finish task in episode 136
# the reward is -200.0 maxPosition is -0.0024809271562844515
# Failed to finish task in episode 137
# the reward is -200.0 maxPosition is 0.40744417905807495
# Failed to finish task in episode 138
# the reward is -200.0 maxPosition is 0.10848343372344971
# Failed to finish task in episode 139
# the reward is -200.0 maxPosition is 0.056464701890945435
# Failed to finish task in episode 140
# the reward is -200.0 maxPosition is -0.023090321570634842
# Failed to finish task in episode 141
# the reward is -200.0 maxPosition is -0.059333525598049164
# Failed to finish task in episode 142
# the reward is -200.0 maxPosition is -0.0931222140789032
# Failed to finish task in episode 143
# the reward is -200.0 maxPosition is -0.03696608543395996
# Failed to finish task in episode 144
# the reward is -200.0 maxPosition is -0.2286965399980545
# Failed to finish task in episode 145
# the reward is -200.0 maxPosition is -0.07160129398107529
# Failed to finish task in episode 146
# the reward is -200.0 maxPosition is -0.32154834270477295
# Failed to finish task in episode 147
# the reward is -200.0 maxPosition is -0.014063083566725254
# Failed to finish task in episode 148
# the reward is -200.0 maxPosition is 0.08441583067178726
# Failed to finish task in episode 149
# the reward is -200.0 maxPosition is -0.05287235230207443
# Failed to finish task in episode 150
# the reward is -200.0 maxPosition is 0.09162253886461258
# Success in episode 151, used 169 iterations!
# the reward is -160.0 maxPosition is 0.5067973732948303
# Failed to finish task in episode 152
# the reward is -200.0 maxPosition is 0.21447817981243134
# Failed to finish task in episode 153
# the reward is -200.0 maxPosition is -0.07436193525791168
# Failed to finish task in episode 154
# the reward is -200.0 maxPosition is -0.022516930475831032
# Failed to finish task in episode 155
# the reward is -200.0 maxPosition is -0.3595083951950073
# Success in episode 156, used 162 iterations!
# the reward is -153.0 maxPosition is 0.5010589957237244
# Failed to finish task in episode 157
# the reward is -200.0 maxPosition is -0.10369116812944412
# Failed to finish task in episode 158
# the reward is -200.0 maxPosition is -0.09523525834083557
# Failed to finish task in episode 159
# the reward is -200.0 maxPosition is 0.08055715262889862
# Failed to finish task in episode 160
# the reward is -200.0 maxPosition is -0.42845821380615234
# Failed to finish task in episode 161
# the reward is -200.0 maxPosition is 0.4212493300437927
# Failed to finish task in episode 162
# the reward is -200.0 maxPosition is 0.024486444890499115
# Failed to finish task in episode 163
# the reward is -200.0 maxPosition is -0.2943129539489746
# Failed to finish task in episode 164
# the reward is -200.0 maxPosition is -0.08348982036113739
# Failed to finish task in episode 165
# the reward is -200.0 maxPosition is -0.12611666321754456
# Failed to finish task in episode 166
# the reward is -200.0 maxPosition is -0.11814238876104355
# Failed to finish task in episode 167
# the reward is -200.0 maxPosition is -0.2729291319847107
# Failed to finish task in episode 168
# the reward is -200.0 maxPosition is 0.0035654553212225437
# Failed to finish task in episode 169
# the reward is -200.0 maxPosition is 0.1371670663356781
# Failed to finish task in episode 170
# the reward is -200.0 maxPosition is -0.24362321197986603
# Success in episode 171, used 143 iterations!
# the reward is -134.0 maxPosition is 0.5159740447998047
# Failed to finish task in episode 172
# the reward is -200.0 maxPosition is -0.20847833156585693
# Failed to finish task in episode 173
# the reward is -200.0 maxPosition is -0.05341068655252457
# Failed to finish task in episode 174
# the reward is -200.0 maxPosition is -0.19074051082134247
# Failed to finish task in episode 175
# the reward is -200.0 maxPosition is -0.01758105680346489
# Failed to finish task in episode 176
# the reward is -200.0 maxPosition is 0.15569423139095306
# Failed to finish task in episode 177
# the reward is -200.0 maxPosition is -0.30076056718826294
# Failed to finish task in episode 178
# the reward is -200.0 maxPosition is -0.1339292824268341
# Failed to finish task in episode 179
# the reward is -200.0 maxPosition is -0.21315494179725647
# Failed to finish task in episode 180
# the reward is -200.0 maxPosition is -0.19835303723812103
# Failed to finish task in episode 181
# the reward is -200.0 maxPosition is 0.005628921091556549
# Failed to finish task in episode 182
# the reward is -200.0 maxPosition is -0.24266308546066284
# Failed to finish task in episode 183
# the reward is -200.0 maxPosition is -0.1670316457748413
# Failed to finish task in episode 184
# the reward is -200.0 maxPosition is 0.33406996726989746
# Failed to finish task in episode 185
# the reward is -200.0 maxPosition is -0.20580190420150757
# Failed to finish task in episode 186
# the reward is -200.0 maxPosition is -0.3406449854373932
# Failed to finish task in episode 187
# the reward is -200.0 maxPosition is 0.13131272792816162
# Success in episode 188, used 179 iterations!
# the reward is -170.0 maxPosition is 0.5020087957382202
# Failed to finish task in episode 189
# the reward is -200.0 maxPosition is -0.007496865466237068
# Success in episode 190, used 174 iterations!
# the reward is -165.0 maxPosition is 0.514785885810852
# Failed to finish task in episode 191
# the reward is -200.0 maxPosition is -0.05337812751531601
# Failed to finish task in episode 192
# the reward is -200.0 maxPosition is -0.08323896676301956
# Failed to finish task in episode 193
# the reward is -200.0 maxPosition is 0.4863320291042328
# Failed to finish task in episode 194
# the reward is -200.0 maxPosition is -0.15207256376743317
# Failed to finish task in episode 195
# the reward is -200.0 maxPosition is -0.15976375341415405
# Failed to finish task in episode 196
# the reward is -200.0 maxPosition is -0.17935819923877716
# Failed to finish task in episode 197
# the reward is -200.0 maxPosition is -0.05790707841515541
# Success in episode 198, used 116 iterations!
# the reward is -107.0 maxPosition is 0.5152681469917297
# Failed to finish task in episode 199
# the reward is -200.0 maxPosition is -0.3142396807670593
# Failed to finish task in episode 200
# the reward is -200.0 maxPosition is 0.38790273666381836
# Failed to finish task in episode 201
# the reward is -200.0 maxPosition is -0.18304291367530823
# Failed to finish task in episode 202
# the reward is -200.0 maxPosition is 0.32166042923927307
# Failed to finish task in episode 203
# the reward is -200.0 maxPosition is 0.26167696714401245
# Failed to finish task in episode 204
# the reward is -200.0 maxPosition is -0.3608729839324951
# Failed to finish task in episode 205
# the reward is -200.0 maxPosition is -0.3385673761367798
# Failed to finish task in episode 206
# the reward is -200.0 maxPosition is -0.35891193151474
# Success in episode 207, used 196 iterations!
# the reward is -187.0 maxPosition is 0.5102415680885315
# Success in episode 208, used 188 iterations!
# the reward is -179.0 maxPosition is 0.5077926516532898
# Success in episode 209, used 148 iterations!
# the reward is -139.0 maxPosition is 0.5156709551811218
# Failed to finish task in episode 210
# the reward is -200.0 maxPosition is -0.3835736811161041
# Failed to finish task in episode 211
# the reward is -200.0 maxPosition is -0.34640905261039734
# Failed to finish task in episode 212
# the reward is -200.0 maxPosition is 0.11179383844137192
# Failed to finish task in episode 213
# the reward is -200.0 maxPosition is 0.15142172574996948
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done

# %%
env = gym.make('MountainCar-v0')
plot_animation(dqn.train_network, env, gif_name=f"DQN_final.gif")
env.close()
